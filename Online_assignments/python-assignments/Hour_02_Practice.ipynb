# %%
#In [1]:
#Write 5 print statements that output your favorite movies.

print("My first facorite movie is PEDDI")
print("MY Second favaorite movie is RRR")
print("My Thrid Favaorite movie is  ANIMAL")
print("My Fouth favaorite movie is KGF")
print("my Fivth favaorite movie is SALAAR")
# Out:
# My first facorite movie is PEDDI
# MY Second favaorite movie is RRR
# My Thrid Favaorite movie is  ANIMAL
# My Fouth favaorite movie is KGF
# my Fivth favaorite movie is SALAAR

# %%
#In [2]:
#Write 5 print statements displaying numbers 1 to 5, each separated by a tab character (\t).

print(1, end="\t")
print(2, end="\t")
print(3, end="\t")
print(4, end="\t")
print(5, end="\t")
# Out:
# 1	2	3	4	5

# %%
#In [3]:
#Write 5 print statements displaying names of cities, using the sep=' | ' argument.

print("Mumbai","pune","banglore", sep="|")
print("HYD","CHennai","Tirupati",sep="|")
print("goa","lucknow",sep="|")
print("kurnool","kadapa", sep="|")
print("waranagal","kochi","chennai", sep="|")
# Out:
# Mumbai|pune|banglore
# HYD|CHennai|Tirupati
# goa|lucknow
# kurnool|kadapa
# waranagal|kochi|chennai

# %%
#In [4]:
#Write 5 print statements that print parts of a single sentence sequentially without starting new lines (using end=' ').

print("My name", end=' ')
print('is',end=' ')
print("Yuvateja", end="")
print(". Hello",end=" ")
print("world!")
# Out:
# My name is Yuvateja. Hello world!

# %%
#In [5]:
#Intentionally create an IndentationError by mixing spaces and tabs, then write down how you resolved it.

#print(my name is yuvateja ) # in this line of code i called print statment with out ""
                            #  so it throwed into error 
                            # 
print("My name is Yuvateja")  # here i fixed with proper indentation
                            # so it's printed the statement
# Out:
# My name is Yuvateja

# %%
#In [6]:
#Write a multi-line comment describing your daily routine.


# I woke up around 8am in the morning. 
# Post i get ready i will have my tea and i will skip my breakfast.
# After i have tea on the way to insititute i will attend the classes from 9.30AM to 12PM.
# Post class i will walk back to pg.
# I will have my lunch. 
# Post lunch i will have a small nap and again i will start my office work upto 11PM.

# %%
#In [7]:
#Use a comment to disable a line of code, leaving only the active code running.

name = "Yuvateja"
#family_name = "Kulapatti"

print(name) #since i comment family_name when i search for
            # that variable in print statemtn it will not visible.
# Out:
# Yuvateja

# %%
#In [8]:
#Print the symbol of a heart or smiley face using unicode characters.

print("\u2665","\u263A", sep="\n")
# Out:
# ♥
# ☺

# %% [markdown]
# In [9]:
# Explain what happens if you indent a statement that is not inside any block.
#
# it will throw indentation error

# %%
#In [10]:
#Write a print statement that prints the math equation '5 + 5 = 10' by combining text and numbers.

print(f" The math equation 5 + 5 = {5+5}")
# Out:
#  The math equation 5 + 5 = 10
