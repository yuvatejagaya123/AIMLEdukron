# %% [markdown]
# In [1]:
# Install Python 3.x and Jupyter Notebook (via Anaconda or pip). Take a screenshot of your working Jupyter Notebook interface.
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In [2]:
# Create a new notebook and name it 'Hour_01_Practice.ipynb'.
#
# ![image.png](attachment:image.png)

# %%
#In [3]:
#Write a program to print your name, email, and city on three separate lines.

print("My name is Yuvateja")
print('my email id is yuvatejagaya123gmail.com')
print("I am current living in banglore")
# Out:
# My name is Yuvateja
# my email id is yuvatejagaya123gmail.com
# I am current living in banglore

# %% [markdown]
# In [4]:
# Explain the difference between a Code cell and a Markdown cell in Jupyter.
#
# Code cell - It is used to bulit and excute the program.
# markdown cell - it is used to add headings, or text which we need to define sometime as representation.

# %% [markdown]
# In [5]:
# List 3 popular keyboard shortcuts in Jupyter Notebook and what they do.
#
# shift + enter = to excute the cell and swift to next same kind of cell
# control + enter = in will excute the cell and stays in the same cell
# control + m + z = used to undo cell.

# %%
#In [6]:
#Write a print statement that uses double quotes inside the string, e.g., 'Python is "awesome"'.

string = 'Python is "awesome"'

print(string)
# Out:
# Python is "awesome"

# %%
#In [7]:
#Perform a simple addition of three numbers (e.g., 10, 20, 30) and print the result.

print(10+20+30)
# Out:
# 60

# %% [markdown]
# In [8]:
# Create a markdown cell explaining what an interpreted language is.
#
# interpreted - it will excute the source code line by line.

# %%
#In [9]:
#Write a print statement that prints a multi-line message using a single print statement (hint: search for triple quotes).

print('''
My Name is Yuvateja
I love eating
I am dancer 
             
''')
# Out:
# My Name is Yuvateja
# I love eating
# I am dancer

# %%
#In [10]:
#Run a command in Jupyter to check your current Python version (hint: import sys; print(sys.version)).
import sys
print(sys.version)
# Out:
# 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
