# %%
#In [1]:
#Create a variable 'student_name' and assign your name to it. Print it.

student_name = "Yuvateja"
print(student_name)
# Out:
# Yuvateja

# %%
#In [2]:
#Create a variable 'course_name' and assign 'Python Data Science' to it. Print it.

course_name = "Python Data Science"
print(course_name)
# Out:
# Python Data Science

# %%
#In [3]:
#Create a variable 'course_fee' and assign 1500.50 to it. Print it.

course_fee = 1500.50

print(course_fee)
# Out:
# 1500.5

# %%
#In [4]:
#Create a variable 'discount' and assign 150 to it. Calculate and print 'final_fee'.
fee = 4000
discount = 150
final_fee = fee - discount
print(final_fee)
# Out:
# 3850

# %%
#In [5]:
#Write code to assign the value 100 to three variables x, y, and z at once.

x = y = z = 100
print(x)
print(y)
print(z)
# Out:
# 100
# 100
# 100

# %%
#In [6]:
#Demonstrate variable name case-sensitivity by creating 'data' and 'Data' with different values.

data = "yuva"
Data = 1234

print(f"{data} : {Data}")
print(data, ":", Data)
# Out:
# yuva : 1234
# yuva : 1234

# %%
#In [6]:
#Demonstrate variable name case-sensitivity by creating 'data' and 'Data' with different values.

house_no = 21
street = "hemanth nagar"
city = "Banglore"
pincode = 67890

print(house_no,street,city,pincode, sep=",")
# Out:
# 21,hemanth nagar,Banglore,67890

# %% [markdown]
# In [8]:
# List 5 invalid variable names and explain why they are invalid.
#
# name = yuvateja  # invalid because i am caling name without "" - str always should be in "" or ''
#
# if = yuvateja    # if is a keyword so we can't use it as variable
#
# 2name = yuvateja # number can't be used as variable
#
# age = "100"      # this will be valid only but the value in the age will be treated as str instead of int. for Int we should not use ""
#                  # anything bewtween " " is treated as str.
#
# sum = 1234       # her we are use sum as variable and in the print statement if we call sum(1234) it will be throw into error
#                  # so always ignore in bulit funtions as variable

# %%
#In [9]:
#Assign your age to variable 'my_age'. Add 5 to it and update the same variable. Print the updated value.

my_age = 26
updated_value = 5
updated_age = my_age + updated_value
print(updated_age)
# Out:
# 31

# %% [markdown]
# In [10]:
# Explain what dynamic typing means in your own words with code examples.
#
# dynamic typing means declarion of variable data type - In python - We need not want to declare the type of variable data.
