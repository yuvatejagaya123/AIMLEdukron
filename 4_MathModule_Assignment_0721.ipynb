# %%
#1. Write a program to calculate the square root of a number using the math module.
import math

math.sqrt(100)
# Out:
# 10.0

# %%
# 2. Find the cube root of a given number using mathematical operations.

math.cbrt(125)
# Out:
# 5.0

# %%
#3. Find the GCD (Greatest Common Divisor) of two numbers using math.gcd().

math.gcd(25,90)
# Out:
# 5

# %%
#4.Find the LCM of two numbers using math.lcm().

math.lcm(10,55)
# Out:
# 110

# %%
#6.Calculate the value of 5 raised to the power of 8 using math.pow().

math.pow(5,8)
# Out:
# 390625.0

# %%
#7. Find the absolute value of a negative decimal number using math.fabs().

math.fabs(-100)
# Out:
# 100.0

# %%
#8. Round a floating-point number up using math.ceil().

math.ceil(67.9987)
# Out:
# 68

# %%
#9. Round a floating-point number down using math.floor().

math.floor(67.9987)
# Out:
# 67

# %%
#10. Round a floating-point number to the nearest integer using round().

round(67.9987)
# Out:
# 68

# %%
#11. Find the remainder of two numbers using math.fmod().

math.fmod(80,21)
# Out:
# 17.0

# %%
#12. Find the quotient and remainder using divmod().

divmod(90,2)
# Out:
# (45, 0)

# %%
#13. Calculate the sine, cosine, and tangent of 45 degrees.

x = math.sin(45)
y= math.cos(45)
z= math.tan(45)

print(x,y,z)
# Out:
# 0.8509035245341184 0.5253219888177297 1.6197751905438615

# %%
#14. Convert an angle from degrees to radians.

math.radians(90) ##pi/180
# Out:
# 1.5707963267948966

# %%
#15. Convert an angle from radians to degrees.

math.degrees(1.5707963267948966) ## 180/pi
# Out:
# 90.0

# %%
#16. Find the logarithm (base 10) of a number using math.log10().

math.log10(100)
# Out:
# 2.0

# %%
#17. Find the natural logarithm of a number using math.log().

math.log(10)
# Out:
# 2.302585092994046

# %%
#18 .Calculate e raised to the power of x using math.exp().

math.exp(2)
# Out:
# 7.38905609893065

# %%
#19. Find the value of π (pi) and Euler's number (e) from the math module.

x = math.pi
y = math.e

x,y
# Out:
# (3.141592653589793, 2.718281828459045)

# %%
#20. Find the distance between two points using math.dist().
math.dist((4,5),(10,20))
# Out:
# 16.15549442140351

# %%
#21. Calculate the hypotenuse of a right triangle using math.hypot()

math.hypot(10,30)
# Out:
# 31.622776601683793

# %%
#22 Find the combination (nCr) using math.comb().

math.comb(10,5)
# Out:
# 252

# %%
#23.Find the permutation (nPr) using math.perm().

math.perm(10,5)
# Out:
# 30240

# %%
#24. CCheck whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

x = math.isfinite(10)
y = math.isinf(10)
z = math.isnan(10)

x,y,z
# Out:
# (True, False, False)

# %%
#25 Find the product of all numbers in a list using math.prod().

x= [1,2,3,4]

math.prod(x)
# Out:
# 24

# %%
#26. Find the sum of square roots of all numbers in a list.
x = [2,3,4,5]
math.sqrt(sum(x))
# Out:
# 3.7416573867739413

# %%
#27. Find the largest integer less than or equal to the square root of a given number.


n = int(input("Enter a number: "))
math.isqrt(n)
# Out:
# Enter a number: 60
# 7

# %%
#28. Calculate compound interest using math.pow().
p = 500
r = 10  #rate of interst
t = 2      # time(years)

a = p * math.pow((1 + r / 100), t)
CI = a - p

print(f"'compound interst' = {CI}")
# Out:
# 'compound interst' = 105.00000000000011

# %%
#29. Find the area and circumference of a circle using math.pi.

r = 10

#area = pi * r * 2   r = radius
#circumference = 2pi * r * 2

A = math.pi * 10 ** 2
C = 2 * math.pi * 10
print(f"Area = {A},circumference = {C}")
# Out:
# Area = 314.1592653589793,circumference = 62.83185307179586

# %%
#30. Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

print("1 = Square root" )
print("2 = Factorial")
print("3 = Logarithm")
print("4 = Power")
print("5 = Trigonometric Function")
print("6 = GCD")
print("7 = LCM")

choice = int(input('Enter the choice: '))

if choice == 1:
  num = float(input("Enter the number:"))
  print(f"square root of {num} is ",math.sqrt(num))

elif choice == 2:
  num1 = int(input("enter the number:"))
  print(f"factorial of {num1} is", math.factorial(num1))

elif choice == 3:
  num3 = float(input("Enter the number:"))
  print(f"log()- natural logarithm of {num3} is", math.log(num3))
  print(f"log10()- base  10 of {num3} is", math.log10(num3))
  print(f"log2()- base 2 of {num3} is", math.log2(num3))

elif choice == 4:
  base = int(input("Enter the base value:"))
  exponent = int(input("Enter the exponent value:"))
  print(f"{base} to the power of {exponent} is ", math.pow(base,exponent))

elif choice == 5:
  angle = float(input("Enter the angle:"))

  radians = math.radians(angle)

  print(f"sin angle of {angle}", math.sin(radians))
  print(f"cos angle of {angle}", math.cos(radians))
  print(f"tan angle of {angle}", math.tan(radians))

elif choice == 6:
  num4 = int(input("Enter the 1st number:"))
  num5 = int(input("Enter the 2nd number:"))

  print(f"GCD of {num4,num5} is", math.gcd(num4,num5))

elif choice == 7:
  num6 = int(input("Enter the 1st number:"))
  num7= int(input("Enter the 2nd number:"))

  print(f"LCM of {num6,num7} is", math.lcm(num6,num7))

else:
  print("Invaild choice")
# Out:
# 1 = Square root
# 2 = Factorial
# 3 = Logarithm
# 4 = Power
# 5 = Trigonometric Function
# 6 = GCD
# 7 = LCM
# Enter the choice: 6
# Enter the 1st number:45
# Enter the 2nd number:50
# GCD of (45, 50) is 5

# %%
# Python Operators – 30 Coding Questions
# 1. Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

print("1 = Addition")
print("2 = Subtraction")
print("3 = Multiplication")
print("4 = division")
print("5 = floor division")
print("6 = Modulus")
print("7 = exponentiation")

choice = float(input("Enter the chocice : "))
Number_1 = float(input("Enter the 1st Number :"))
Number_2 = float(input("Enter the 2nd Number : "))

if choice == 1:
  Addition = Number_1 + Number_2
  print(f"Addition of {Number_1} & {Number_2} is", Addition)

elif choice ==2:
  Subtraction = Number_1 - Number_2
  print(f"subtraction of {Number_1} & {Number_2} is", Subtraction)

elif choice == 3:
  Multiplication = Number_1 * Number_2
  print(f"Multiplication of {Number_1} & {Number_2} is", Multiplication)

elif choice == 4:
  division = Number_1 / Number_2
  print(f"Division of {Number_1} & {Number_2} is", division)

elif choice == 5:
  floor_division = Number_1 // Number_2
  print(f"floor_division of {Number_1} & {Number_2} is", floor_division)

elif choice == 6:
  modulus = Number_1 % Number_2
  print(f"Modulus of {Number_1} & {Number_2} is", modulus)

elif choice == 7:
  exponentiation = Number_1 ** Number_2
  print(f"exponentiation of {Number_1} & {Number_2} is", exponentiation)

else:
  print("Invalid choice")
# Out:
# 1 = Addition
# 2 = Subtraction
# 3 = Multiplication
# 4 = division
# 5 = floor division
# 6 = Modulus
# 7 = exponentiation
# Enter the chocice : 5
# Enter the 1st Number :56
# Enter the 2nd Number : 5
# floor_division of 56.0 & 5.0 is 11.0

# %%
#2. Swap two numbers without using a third variable.

x = 45
y = 55

x,y = y,x
print(x)
print(y)
# Out:
# 55
# 45

# %%
#3. Find whether a number is even or odd using the modulus operator.
x = 50

if x % 2 == 0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Even Number

# %%
#4. Reverse a three-digit number using arithmetic operators.

x = 675

hund = x // 100
ten = (x //10) % 10
one = x % 10

reverse_x = one * 100 + ten *10 + hund
reverse_x
# Out:
# 576

# %%
#5. Find the last digit and first digit of a given number.

x = 123456789

last_digit = x % 10


first_digit = x
while first_digit >= 10:
    first_digit = first_digit // 10

print("First digit:", first_digit)
print("Last digit:", last_digit)
# Out:
# First digit: 1
# Last digit: 9

# %%
#6. Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

a = 100
print("Initial value:", a)

a += 5  # here we are adding the value to a
print("+= :", a)

a -= 3 # here we are subtracting
print("-= :", a)

a *= 2 # here we are multipling
print("*= :", a)

a /= 4 # this is division
print("/= :", a)

a //= 2 # this is floor division
print("//= :", a)

a %= 3 # getting remeiber
print("%= :", a)

a **= 2 # powering the value
print("**= :", a)

## in this case a value is reducing it will not take the initial value.
##so that is why output is differ.
# Out:
# Initial value: 100
# += : 105
# -= : 102
# *= : 204
# /= : 51.0
# //= : 25.0
# %= : 1.0
# **= : 1.0

# %%
#7. Update a bank account balance using compound assignment operators.

balance = 3000

balance += 4000 # Deposit
print("After deposit balance is",balance)

balance -= 1600 # Withdraw
print("Balance after Withdraw",balance)
# Out:
# After deposit balance is 7000
# Balance after Withdraw 5400

# %%
#8. Calculate the total marks using += inside a loop.

marks = [50,89,100,60,]
total_marks = 0
for mark in marks:
  total_marks += mark

print("Total Marks: ", total_marks)
# Out:
# Total Marks:  299

# %%
#9. Compare two numbers and print the larger number.

x = 80
y = 90

if x > y:
  print(x,"Is the largest Number which Is Variable 'x'")
else:
 print(y,"is the Largest Number which Is Variable 'y'")
# Out:
# 90 is the Largest Number which Is Variable 'y'

# %%
#10. Check whether three numbers are equal.

x = 50
y = 50
z = 50

if x == y == z:
  print("All Values are equal")
else:
  print("Values are different")
# Out:
# All Values are equal

# %%
#11. Find the largest among three numbers using comparison operators.

x = 100
y = 540
z = 500

if x > y and x > z:
  print("x variable is larger", x)
elif y > x and y >z:
  print("y variable is larger",y)
elif z > x and z > y:
  print("z variable is larger ",z)
else:
  print("All variables are same")
# Out:
# y variable is larger 540

# %%
#12. Check whether a student is eligible to vote based on age.

student_age = 22

if student_age >= 18:
  print("Eligible to Vote")
else:
  print("Not Eligible")
# Out:
# Eligible to Vote

# %%
#13. Check if a person is eligible for a loan (age > 21 AND salary > 30000).

age = 28
salary = 60000

if age > 21 and salary > 30000:
  print("Eligible for Loan")
else:
  print("Not Eligible")
# Out:
# Eligible for Loan

# %%
#14. Check if a number lies between 10 and 100 using logical operators.
x = float(input("Enter the Number:"))

if x > 10 and x < 100:
  print("Number is between 10 and 100")
else:
  print("Number is not between 10 and 100")
# Out:
# Enter the Number:89
# Number is between 10 and 100

# %%
#15. Validate username and password using logical operators.
username = str(input("Enter Username:"))
password = str(input("Enter Password:"))

if len(username) >10 and len(password)>12:
  print("Valid")
else:
  print("Not Valid")
# Out:
# Enter Username:yuvateja89
# Enter Password:Yuvateja@1432
# Not Valid

# %%
#16. Determine whether a year is a leap year using logical conditions.

year = int(input("Enter the Year: "))

if year % 4 == 0 and year % 100 != 0:
  print(year, "Is Leap Year")
else:
  print(year, "Is not leap Year")
# Out:
# Enter the Year: 2026
# 2026 Is not leap Year

# %%
#17. Find the bitwise AND, OR, XOR of two numbers.

x = 19
y = 20

print("Bitwise AND", x & y)
print("Bitwise OR", x | y)
print("Bitwise Xor", x ^ y)
# Out:
# Bitwise AND 16
# Bitwise OR 23
# Bitwise Xor 7

# %%
#18. Perform left shift and right shift operations.
x = 3
print(x << 1) # left shift
print(x >> 1) # right shift with 2 power 1
print(x >> 2) # right shift with 2 power 2
# Out:
# 6
# 1
# 0

# %%
#19. Check whether a number is even using a bitwise operator.

num = 20

if num & 1 == 0:
  print("Even")
else:
  print("ODD")
# Out:
# Even

# %%
#20. Swap two numbers using the XOR operator.

x = 9
y = 10

x = x ^ y
y = x ^ y
x = x ^ y

x,y
# Out:
# (10, 9)

# %%
#21. Count how many bits are set to 1 in a number using bitwise operations.

num = int(input("Enter a number: "))

count = 0

while num > 0:
    if num & 1:
        count += 1
    num = num >> 1

print("Number of bits:", count)
# Out:
# Enter a number: 89
# Number of bits: 4

# %%
#22.Demonstrate the difference between is and ==.

x = (1,2,4)
y = (1,2,4)

print(x==y) ## == check the values in the variable
print(x is y) ## is check the value are from same memory
# Out:
# True
# False

# %%
#23. Check whether two variables refer to the same list object.

x = [1,2,3,4,5]
y = x

if x is y:
  print("Two variable x & y are from same list")
else:
  print("Not from same list")
# Out:
# Two variable x & y are from same list

# %%
#24.Show the behavior of is not with integers and lists.

x = ["data","science"]
y = ["science","data"]
a = 10
b = 20

###For list
if x is not y:
  print("x is not object of y")
else:
  print("x is object of y")
### For Intergers
if a is not b:
  print("a is not object of b")
else:
  print("a is object of b")
# Out:
# x is not object of y
# a is not object of b

# %%
#25.Check whether a character exists in a string.

name = "My name is Yuvateja"

if "a" in name:
  print("Character exsits in variable")
else:
  print("character not exsits in variable")
# Out:
# Character exsits in variable

# %%
#26.Check whether a number exists in a list.
x = [1,2,3,4]

if 200 in x:
  print("Exists")
else:
  print("Not Exists")
# Out:
# Not Exists

# %%
#27. Count how many vowels in a string belong to a predefined vowel list using in.

x = "My name is yuvateja"
count = 0
for i in x:
  if i in "aeiou":
    count += 1
print(count)
# Out:
# 7

# %%
#28. Build a simple calculator using arithmetic and comparison operators.


# Simple Calculator

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Choose an operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")
print("5. Modulus (%)")
print("6. Floor Division (//)")
print("7. Exponentiation (**)")

choice = input("Enter your choice (1-7): ")

if choice == "1":
    print("Result:", num1 + num2)
elif choice == "2":
    print("Result:", num1 - num2)
elif choice == "3":
    print("Result:", num1 * num2)
elif choice == "4":
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Division by zero is not allowed.")
elif choice == "5":
    if num2 != 0:
        print("Result:", num1 % num2)
    else:
        print("Division by zero is not allowed.")
elif choice == "6":
    if num2 != 0:
        print("Result:", num1 // num2)
    else:
        print("Division by zero is not allowed.")
elif choice == "7":
    print("Result:", num1 ** num2)
else:
    print("Invalid choice.")

# Comparison Operators
print("\nComparison Results:")
print("num1 == num2 :", num1 == num2)
print("num1 != num2 :", num1 != num2)
print("num1 > num2  :", num1 > num2)
print("num1 < num2  :", num1 < num2)
print("num1 >= num2 :", num1 >= num2)
print("num1 <= num2 :", num1 <= num2)
# Out:
# Enter first number: 8
# Enter second number: 7
# Choose an operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Modulus (%)
# 6. Floor Division (//)
# 7. Exponentiation (**)
# Enter your choice (1-7): 1
# Result: 15.0
#
# Comparison Results:
# num1 == num2 : False
# num1 != num2 : True
# num1 > num2  : True
# num1 < num2  : False
# num1 >= num2 : True
# num1 <= num2 : False

# %%
#29. Create a grading system using comparison and logical operators.

marks = int(input("Enter the marks(0-100): "))

if marks >= 90 and marks <= 100:
  print("Grade - A")
elif marks >= 80 and marks <= 90:
  print("Grade - B")
elif marks >= 60 and marks <= 80:
  print("Grade - c")
elif marks >= 35 and marks <= 60:
  print("grade - D")
elif marks < 35:
  print("Fail")
else:
  print("Invalid Marks" )
# Out:
# Enter the marks(0-100): 90
# Grade - A

# %%
#30. Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

print("===== MENU DRIVEN CALCULATOR =====")
print("1. Arithmetic Operations")
print("2. Comparison Operations")
print("3. Logical Operations")
print("4. Assignment Operations")
print("5. Membership Operations")
print("6. Identity Operations")
print("7. Bitwise Operations")

choice = int(input("Enter your choice: "))

if choice == 1:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    print("Addition:", a + b)
    print("Subtraction:", a - b)
    print("Multiplication:", a * b)

    if b != 0:
        print("Division:", a / b)
        print("Floor Division:", a // b)
        print("Modulus:", a % b)
    else:
        print("Division by zero is not allowed.")

    print("Exponentiation:", a ** b)

elif choice == 2:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    print("a == b :", a == b)
    print("a != b :", a != b)
    print("a > b  :", a > b)
    print("a < b  :", a < b)
    print("a >= b :", a >= b)
    print("a <= b :", a <= b)

elif choice == 3:
    x = input("Enter True/False for x: ") == "True"
    y = input("Enter True/False for y: ") == "True"

    print("x and y :", x and y)
    print("x or y  :", x or y)
    print("not x   :", not x)

elif choice == 4:
    a = int(input("Enter a number: "))

    a += 5
    print("After += 5 :", a)

    a -= 2
    print("After -= 2 :", a)

    a *= 3
    print("After *= 3 :", a)

    a //= 2
    print("After //= 2 :", a)

elif choice == 5:
    items = ["apple", "banana", "mango"]

    item = input("Enter fruit name: ")

    print(item in items)
    print(item not in items)

elif choice == 6:
    list1 = [1, 2, 3]
    list2 = [1, 2, 3]
    list3 = list1

    print("list1 is list2 :", list1 is list2)
    print("list1 is list3 :", list1 is list3)
    print("list1 is not list2 :", list1 is not list2)

elif choice == 7:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))

    print("AND (&):", a & b)
    print("OR (|):", a | b)
    print("XOR (^):", a ^ b)
    print("Left Shift (<<1):", a << 1)
    print("Right Shift (>>1):", a >> 1)

else:
    print("Invalid Choice!")
# Out:
# ===== MENU DRIVEN CALCULATOR =====
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operations
# 5. Membership Operations
# 6. Identity Operations
# 7. Bitwise Operations
# Enter your choice: 1
# Enter first number: 8
# Enter second number: 9
# Addition: 17
# Subtraction: -1
# Multiplication: 72
# Division: 0.8888888888888888
# Floor Division: 0
# Modulus: 8
# Exponentiation: 134217728
